# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 76.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# --- Install dependencies ---
# !pip install roboflow

# --- Import and authenticate ---
from roboflow import Roboflow
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# --- Connect to Roboflow ---
rf = Roboflow(api_key="iqWudABIjfXqATDPAmLo")  # replace with your Roboflow API key

# --- Load your project and version ---
# Example: workspace("hazard-ai").project("weapons-detection").version(1)
project = rf.workspace("custome-yolo").project("all-weapons-data-jqimy")
dataset = project.version(1).download("yolov8")

# --- Copy dataset to Drive ---
# !cp -r {dataset.location} /content/drive/MyDrive/
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to All-weapons-data-1 in yolov8:: 100%|██████████| 17172/17172 [00:07<00:00, 2412.08it/s]

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/CNN")  # or any custom folder
print("Now working in:", os.getcwd())
# Out:
# Now working in: /content/drive/MyDrive/Colab Notebooks/CNN
